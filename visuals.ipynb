# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Create the synthetic data
data = pd.DataFrame({
    "region": ["West", "West", "East", "East", "South", "South", "West", "East"],
    "product": ["A", "B", "A", "B", "A", "B", "A", "A"],
    "revenue": [200, 150, 300, 120, 180, 220, 250, 275],
    "quantity": [2, 1, 3, 1, 2, 2, 2, 3]
})

data
# Out:
#   region product  revenue  quantity
# 0   West       A      200         2
# 1   West       B      150         1
# 2   East       A      300         3
# 3   East       B      120         1
# 4  South       A      180         2
# 5  South       B      220         2
# 6   West       A      250         2
# 7   East       A      275         3

# %%
# Creating a Bar Chart(Comparing catergories)

# What is the total
# revenue by region


# Groupby Aggregation
revenue_by_region = (
    data
    .groupby("region")["revenue"]
    .sum()
    .reset_index()
)

revenue_by_region
# Out:
#   region  revenue
# 0   East      695
# 1  South      400
# 2   West      600

# %%
# Creating the bar chart
plt.figure()
plt.bar(revenue_by_region["region"], revenue_by_region["revenue"])
plt.xlabel("Region")
plt.ylabel("Total Revenue")
plt.title("Total Revenue by Region")
plt.show()

# %%
# Line Chart(Trends over time)
